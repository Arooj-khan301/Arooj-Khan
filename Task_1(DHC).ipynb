# %% [markdown]
# <a href="https://colab.research.google.com/github/Arooj-khan301/Arooj-Khan/blob/main/Task_1(DHC).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task 1:** *Exploring and Visualizing he Iris Dataset*
#
# 1: Load the dataset
#
# 2: Explore structure and statistics
#
# 3: Visualize feature using scatter plots, histogram, and box plots

# %%
                     # Step 1: Importing libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
                     # Step 2: Load the Iris dataset
iris= sns.load_dataset('iris')

# %%
                     # Step 3: Inspect the Dataset
print("Dataset Shape:", iris.shape)
print("\nColumn Names:", iris.columns)
print("\nFirst few Rows")
print(iris.head())

print("\nDataset Info:")
print(iris.info())

print("\nSummary Statistics:")
print(iris.describe)
# Out:
# Dataset Shape: (150, 5)
#
# Column Names: Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
#
# First few Rows
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
# ...

# %%
                         #Step 4: Visualization
#Scatter Plot
plt.figure(figsize=(8,6))
sns.scatterplot(x='sepal_length', y='sepal_width', hue='species', data=iris)
plt.title("Scatter Plot: Sepal Length vs Sepal width")
plt.show()

# %%
#Histogram
iris.hist(figsize=(10,8))
plt.suptitle("Histograms of Iris Features")
plt.show()

# %%
#Box Plot
plt.figure(figsize=(10,6))
sns.boxplot(data=iris)
plt.title("Box plot of Iris features")
plt.show()
